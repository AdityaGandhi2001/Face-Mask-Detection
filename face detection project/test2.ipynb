# %%
import cv2
import numpy as np

# %%
with_mask=np.load("/Users/vinayakgandhi/Downloads/with_mask.npy")
without_mask=np.load("/Users/vinayakgandhi/Downloads/without_mask.npy")

# %%
with_mask.shape
# Out:
# (100, 50, 50, 3)

# %%
without_mask.shape
# Out:
# (100, 50, 50, 3)

# %%
with_mask=with_mask.reshape(100,50*50*3)
without_mask=without_mask.reshape(100,50*50*3)

# %%
with_mask.shape
# Out:
# (100, 7500)

# %%
without_mask.shape
# Out:
# (100, 7500)

# %%
X=np.r_[with_mask,without_mask]

# %%
X.shape
# Out:
# (200, 7500)

# %%
labels=np.zeros(X.shape[0])

# %%
labels[100:]=1.0

# %%
names={0:'Mask',1:'No Mask'}

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(X,labels,test_size=0.25)

# %%
x_train.shape
# Out:
# (150, 7500)

# %%
from sklearn.decomposition import PCA

# %%
pca=PCA(n_components=3)
x_train=pca.fit_transform(x_train)

# %%
x_train[0]
# Out:
# array([ 1926.52731711, -1063.48165435,  -436.50763457])

# %%
x_train.shape
# Out:
# (150, 3)

# %%
x_train,x_test,y_train,y_test=train_test_split(X,labels,test_size=0.20)

# %%
svm=SVC()
svm.fit(x_train,y_train)
# Out:
# SVC()

# %%
#x_test=pca.transform(x_ test)
y_pred=svm.predict(x_test)

# %%
accuracy_score(y_test,y_pred)
# Out:
# 1.0

# %%
haar_data=cv2.CascadeClassifier('data.xml')
capture=cv2.VideoCapture(0)
data=[]
font=cv2.FONT_HERSHEY_COMPLEX
while True:
    flag,img=capture.read( )
    if flag:
        faces=haar_data.detectMultiScale(img)
        for x,y,w,h in faces:
            cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,255),4)
            face = img[y:y+h,x:x+w,:]
            face = cv2.resize(face,(50,50))
            face = face.reshape(1,-1)
            pred = svm.predict(face)[0] 
            n = names[int(pred)]
            cv2.putText(img,n,(x,y),font,1,(244,250,250),2)
            print(n)
        cv2.imshow('result',img)
        if cv2.waitKey(2)==27:
            break
capture.release( )
cv2.destroyAllWindows( )
# Out:
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# No Mask
# ...
